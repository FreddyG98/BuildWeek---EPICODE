# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
FILE_1 = pd.read_csv(r'C:\Users\alfim\Desktop\prova\prova.csv')
FILE_1
# Out:
#                                    Titolo  \
# 0                                   Wings
# 1                              7th Heaven
# 2                              The Racket
# 3                     The Broadway Melody
# 4                                   Alibi
# ...                                   ...
# 4493                The Boy and the Heron
# 4494                            Elemental
# 4495                               Nimona
# 4496                         Robot Dreams
# 4497  Spider-Man: Across the Spider-Verse
#
#                                             Directed by  \
# 0                                    William A. Wellman
# 1                                         Frank Borzage
# 2                                       Lewis Milestone
# 3                                        Harry Beaumont
# 4                                           Roland West
# ...                                                 ...
# 4493                                     Hayao Miyazaki
# ...

# %%
FILE_1.Budget = FILE_1.Budget.str.split('[')
FILE_1.Budget = FILE_1.Budget.str.get(0)
FILE_1.Budget
# Out:
# 0             $2 million,
# 1           $1.3 million,
# 2                      NaN
# 3               $379,000,
# 4                      NaN
#                ...
# 4493                   NaN
# 4494        $200 million,
# 4495                   NaN
# 4496          €5 million,
# 4497    $100–150 million,
# Name: Budget, Length: 4498, dtype: object

# %%
FILE_1['Box office'] = FILE_1['Box office'].str.split('[')
FILE_1['Box office'] = FILE_1['Box office'].str.get(0)
FILE_1['Box office']
# Out:
# 0       $3.8 million (U.S. and Canada rentals),
# 1                                 $2.5 million,
# 2                                            NaN
# 3                                 $4.4 million,
# 4                                            NaN
#                           ...
# 4493                          US$167.5 million,
# 4494                            $496.4 million,
# 4495                                         NaN
# 4496                                  $717,064,
# 4497                        $690.9,  , million,
# Name: Box office, Length: 4498, dtype: object

# %%
FILE_1['Distributed by'] = FILE_1['Distributed by'].str.split('[')
FILE_1['Distributed by'] = FILE_1['Distributed by'].str.get(0)
FILE_1['Distributed by']
# Out:
# 0                      Paramount Famous Lasky Corporation
# 1                                    Fox Film Corporation
# 2                                      Paramount Pictures
# 3                                     Metro-Goldwyn-Mayer
# 4                                          United Artists
#                               ...
# 4493                                                 Toho
# 4494                  Walt Disney Studios Motion Pictures
# 4495                                              Netflix
# 4496    .mw-parser-output .plainlist ol,.mw-parser-out...
# 4497                              Sony Pictures Releasing
# Name: Distributed by, Length: 4498, dtype: object

# %%
FILE_1['Running time'] = FILE_1['Running time'].str.split('[')
FILE_1['Running time'] = FILE_1['Running time'].str.get(0)
FILE_1['Running time']
# Out:
# 0       Original release:, , 111 minutes,
# 1                                  110 min
# 2                               84 minutes
# 3                              100 minutes
# 4                               90 minutes
#                        ...
# 4493                           124 minutes
# 4494                         101 minutes,
# 4495                          99 minutes,
# 4496                           102 minutes
# 4497                         140 minutes,
# Name: Running time, Length: 4498, dtype: object

# %%
FILE_1.Country = FILE_1.Country.str.split('[')
FILE_1.Country = FILE_1.Country.str.get(0)
FILE_1.Country
# Out:
# 0       United States
# 1       United States
# 2       United States
# 3       United States
# 4       United States
#             ...
# 4493            Japan
# 4494    United States
# 4495    United States
# 4496              NaN
# 4497    United States
# Name: Country, Length: 4498, dtype: object

# %%
FILE_1.to_csv('Prova movies pulito.csv' , index = None)

# %%
FILE_1 = pd.read_csv(r'C:\Users\alfim\Desktop\prova\prova.csv')
FILE_1
# Out:
#                                    Titolo  \
# 0                                   Wings
# 1                              7th Heaven
# 2                              The Racket
# 3                     The Broadway Melody
# 4                                   Alibi
# ...                                   ...
# 4493                The Boy and the Heron
# 4494                            Elemental
# 4495                               Nimona
# 4496                         Robot Dreams
# 4497  Spider-Man: Across the Spider-Verse
#
#                                             Directed by  \
# 0                                    William A. Wellman
# 1                                         Frank Borzage
# 2                                       Lewis Milestone
# 3                                        Harry Beaumont
# 4                                           Roland West
# ...                                                 ...
# 4493                                     Hayao Miyazaki
# ...

# %%
FILE_1['Directed by'] = FILE_1['Directed by'].str.split('[')
FILE_1['Directed by'] = FILE_1['Directed by'].str.get(0)
FILE_1['Directed by']
# Out:
# 0                                      William A. Wellman
# 1                                           Frank Borzage
# 2                                         Lewis Milestone
# 3                                          Harry Beaumont
# 4                                             Roland West
#                               ...
# 4493                                       Hayao Miyazaki
# 4494                                           Peter Sohn
# 4495                                 Nick BrunoTroy Quane
# 4496                                         Pablo Berger
# 4497    .mw-parser-output .plainlist ol,.mw-parser-out...
# Name: Directed by, Length: 4498, dtype: object

# %%
FILE_1['Running time'] = FILE_1['Running time'].str.split('minutes')
FILE_1['Running time'] = FILE_1['Running time'].str.get(0)
FILE_1['Running time']
# Out:
# 0       Original release:, , 111
# 1                         110 min
# 2                             84
# 3                            100
# 4                             90
#                   ...
# 4493                         124
# 4494                         101
# 4495                          99
# 4496                         102
# 4497                         140
# Name: Running time, Length: 4498, dtype: object

# %%
FILE_1.Budget = FILE_1.Budget.str.split('(')
FILE_1.Budget = FILE_1.Budget.str.get(0)
FILE_1.Budget
# Out:
# 0               2000000
# 1              13000000
# 2                    NaN
# 3                379000
# 4                    NaN
#               ...
# 4493                 NaN
# 4494          200000000
# 4495                 NaN
# 4496           €5000000
# 4497    100–150 million
# Name: Budget, Length: 4498, dtype: object

# %%
FILE_1['Box office'] = FILE_1['Box office'].str.split('(')
FILE_1['Box office'] = FILE_1['Box office'].str.get(0)
FILE_1['Box office']
# Out:
# 0           38000000
# 1           25000000
# 2                 NaN
# 3           44000000
# 4                 NaN
#             ...
# 4493    US1675000000
# 4494      4964000000
# 4495              NaN
# 4496          717064
# 4497    6909  000000
# Name: Box office, Length: 4498, dtype: object

# %%
FILE_1.to_csv('Prova movies pulito.csv' , index = None)

# %%
FILE_1 = pd.read_csv(r'C:\Users\alfim\Desktop\prova\movies-pulito.csv')
FILE_1
# Out:
#                                    Titolo  \
# 0                                   Wings
# 1                              7th Heaven
# 2                     The Broadway Melody
# 3                         Hollywood Revue
# 4          All Quiet on the Western Front
# ...                                   ...
# 1679             Raya and the Last Dragon
# 1680         Puss in Boots: The Last Wish
# 1681                          Turning Red
# 1682                            Elemental
# 1683  Spider-Man: Across the Spider-Verse
#
#                                             Directed by  \
# 0                                    William A. Wellman
# 1                                         Frank Borzage
# 2                                        Harry Beaumont
# 3                                       Charles Reisner
# 4                                       Lewis Milestone
# ...                                                 ...
# 1679  .mw-parser-output .plainlist ol,.mw-parser-out...
# ...

# %%
FILE_1['Box office'] = FILE_1['Box office'].str.split('-')
FILE_1['Box office'] = FILE_1['Box office'].str.get(1)
FILE_1['Box office']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1679   NaN
# 1680   NaN
# 1681   NaN
# 1682   NaN
# 1683   NaN
# Name: Box office, Length: 1684, dtype: float64

# %%
FILE_1.Budget = FILE_1.Budget.str.split('-')
FILE_1.Budget = FILE_1.Budget.str.get(1)
FILE_1.Budget
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1679    NaN
# 1680    NaN
# 1681    NaN
# 1682    NaN
# 1683    NaN
# Name: Budget, Length: 1684, dtype: object

# %%
FILE_1['Running time'] = FILE_1['Running time'].str.split('or')
FILE_1['Running time'] = FILE_1['Running time'].str.get(1)
FILE_1['Running time']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1679    NaN
# 1680    NaN
# 1681    NaN
# 1682    NaN
# 1683    NaN
# Name: Running time, Length: 1684, dtype: object

# %%
FILE_1['Running time'] = FILE_1['Running time'].str.split('-')
FILE_1['Running time'] = FILE_1['Running time'].str.get(1)
FILE_1['Running time']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1679   NaN
# 1680   NaN
# 1681   NaN
# 1682   NaN
# 1683   NaN
# Name: Running time, Length: 1684, dtype: float64

# %%
FILE_1['Running time'] = FILE_1['Running time'].str.split(' ')
FILE_1['Running time'] = FILE_1['Running time'].str.get(1)
FILE_1['Running time']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 FILE_1['Running time'] = FILE_1['Running time'].str.split(' ')
#       2 FILE_1['Running time'] = FILE_1['Running time'].str.get(1)
#       3 FILE_1['Running time']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %%
FILE_1['Running time'] = FILE_1['Running time'].str.split('/')
FILE_1['Running time'] = FILE_1['Running time'].str.get(1)
FILE_1['Running time']

# %%
FILE_1.to_csv('Prova movies pulito.csv' , index = None)
